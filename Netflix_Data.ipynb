# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Importing meta data on TV Shoes and Movies on Netflix

# %%
download_path = r"C:\Users\jerem\Downloads"
file_name = "netflix_titles.csv"
file_path = os.path.join(download_path, file_name)


if os.path.exists(file_path):
    print(f"File Found: {file_path}")
else:
    print(f"File Not Found: Check the File name and extension")
# Out:
# File Found: C:\Users\jerem\Downloads\netflix_titles.csv

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df = df[df['country'] == 'United States']

# %%
df
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People              NaN
# 27       s28    Movie             Grown Ups     Dennis Dugan
# 28       s29    Movie            Dark Skies    Scott Stewart
# ...      ...      ...                   ...              ...
# 8791   s8792    Movie           Young Adult    Jason Reitman
# 8793   s8794    Movie  Yours, Mine and Ours     Raja Gosnell
# 8802   s8803    Movie                Zodiac    David Fincher
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %%
df = df.sort_values(by='release_year', ascending=False)

# %%
df
# Out:
#      show_id     type                                          title  \
# 1         s2  TV Show                                  Blood & Water
# 2         s3  TV Show                                      Ganglands
# 3         s4  TV Show                          Jailbirds New Orleans
# 31       s32  TV Show                             Chicago Party Aunt
# 30       s31    Movie                                Ankahi Kahaniya
# ...      ...      ...                                            ...
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#                                                director  \
# 1                                                   NaN
# ...

# %%
df = df.drop(columns='description', axis=1)

# %%
df
# Out:
#      show_id     type                                          title  \
# 1         s2  TV Show                                  Blood & Water
# 2         s3  TV Show                                      Ganglands
# 3         s4  TV Show                          Jailbirds New Orleans
# 31       s32  TV Show                             Chicago Party Aunt
# 30       s31    Movie                                Ankahi Kahaniya
# ...      ...      ...                                            ...
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#                                                director  \
# 1                                                   NaN
# ...

# %%
df = df.drop(columns='listed_in')

# %%
df
# Out:
#      show_id     type                                          title  \
# 1         s2  TV Show                                  Blood & Water
# 2         s3  TV Show                                      Ganglands
# 3         s4  TV Show                          Jailbirds New Orleans
# 31       s32  TV Show                             Chicago Party Aunt
# 30       s31    Movie                                Ankahi Kahaniya
# ...      ...      ...                                            ...
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#                                                director  \
# 1                                                   NaN
# ...

# %%
df = df.drop(columns="cast")

# %%
df
# Out:
#      show_id     type                                          title  \
# 1         s2  TV Show                                  Blood & Water
# 2         s3  TV Show                                      Ganglands
# 3         s4  TV Show                          Jailbirds New Orleans
# 31       s32  TV Show                             Chicago Party Aunt
# 30       s31    Movie                                Ankahi Kahaniya
# ...      ...      ...                                            ...
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#                                                director        country  \
# ...

# %%
df2 = df.dropna()
df2
# Out:
#          type                                          title  \
# 1468    Movie                      What Happened to Mr. Cha?
# 1424    Movie                                       Charming
# 1432  TV Show                           The Idhun Chronicles
# 1410    Movie                  Tribhanga - Tedhi Medhi Crazy
# 1411    Movie                    What Would Sophia Loren Do?
# ...       ...                                            ...
# 8763    Movie                WWII: Report from the Aleutians
# 8739    Movie             Why We Fight: The Battle of Russia
# 8660    Movie  Undercover: How to Operate Behind Enemy Lines
# 7790    Movie                                 Prelude to War
# 8205    Movie                           The Battle of Midway
#
#                          director                                country  \
# 1468                 Kim Dong-kyu                            South Korea
# 1424                 Ross Venokur  Canada, United States, Cayman Islands
# ...

# %%
df2['duration'] = df2['duration'].str.replace(' min', '', regex=False)
df2['duration'] = pd.to_numeric(df2['duration'], errors="coerce")
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_22540\3402112878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['duration'] = df2['duration'].str.replace(' min', '', regex=False)
# C:\Users\jerem\AppData\Local\Temp\ipykernel_22540\3402112878.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['duration'] = pd.to_numeric(df2['duration'], errors="coerce")

# %%
filtered_durations = df2[df2['duration'] > 90.0]

# %%
filtered_durations.head()
# Out:
#        type                          title  \
# 1468  Movie      What Happened to Mr. Cha?
# 1410  Movie  Tribhanga - Tedhi Medhi Crazy
# 1412  Movie                       Wish You
# 91    Movie     The Women and the Murderer
# 81    Movie                           Kate
#
#                                 director        country          date_added  \
# 1468                        Kim Dong-kyu    South Korea     January 1, 2021
# 1410                      Renuka Shahane          India    January 15, 2021
# 1412                         Sung Do-jun    South Korea    January 15, 2021
# 91    Mona Achache, Patricia Tourancheau         France   September 9, 2021
# 81                 Cedric Nicolas-Troyan  United States  September 10, 2021
#
#       release_year rating  duration
# 1468          2021  TV-MA     102.0
# 1410          2021  TV-MA      96.0
# 1412          2021  TV-PG     102.0
# 91            2021  TV-14      92.0
# 81            2021      R     106.0

# %%
# Out:
# <Axes: xlabel='release_year'>
