# %%
import pandas as pd
import numpy as np
import

# %% [markdown]
# Let's load up the hotel booking data

# %%
df = pd.read_csv('hotel-booking-data.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('hotel-booking-data.txt')
#
# NameError: name 'pd' is not defined

# %%
df.describe()
# Out:
#        Room number
# count   153.000000
# mean   3079.326797
# std    1718.791186
# min    1001.000000
# 25%    2001.000000
# 50%    3008.000000
# 75%    4010.000000
# max    7002.000000

# %%
df['Company'].value_counts()
# Out:
# Company
# Leexo           3
# Quinu           3
# Fivechat        3
# Twitterlist     2
# Jayo            2
#                ..
# Twitterwire     1
# Skiba           1
# Tagpad          1
# Innojam         1
# Twitterworks    1
# Name: count, Length: 114, dtype: int64

# %%
df.dropna()
# Out:
#            Date       Company          Person Name  Room number
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0
# ..          ...           ...                  ...          ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0
#
# [134 rows x 4 columns]

# %%
df['Double Room'] = df['Room number'] * 2
df
# Out:
#            Date       Company        Person Name  Room number  Double Room
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0       8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0       4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0       8024.0
# 3        Hotels           NaN                NaN          NaN          NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0       2012.0
# ..          ...           ...                ...          ...          ...
# 190   Cleartrip           NaN                NaN          NaN          NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0       8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0      10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0       2020.0
# 194      Hotels           NaN                NaN          NaN          NaN
#
# [195 rows x 5 columns]

# %%
df2 = df.dropna()

# %%
df2.head()
# Out:
#          Date Company          Person Name  Room number  Double Room
# 0  1-Jan-2022  Avamba    Anatole Ridehalgh       4008.0       8016.0
# 1  1-Jan-2022    Fatz      Aldrich McKevin       2002.0       4004.0
# 2  1-Jan-2022   Leexo      Stanley Hadrill       4012.0       8024.0
# 4  1-Jan-2022  Rhyzio         Lyndell Tice       1006.0       2012.0
# 5  1-Jan-2022   Eadel  Broderic Handscombe       3015.0       6030.0

# %%
df.head()
# Out:
#          Date Company        Person Name  Room number  Double Room
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0       8016.0
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0       4004.0
# 2  1-Jan-2022   Leexo    Stanley Hadrill       4012.0       8024.0
# 3      Hotels     NaN                NaN          NaN          NaN
# 4  1-Jan-2022  Rhyzio       Lyndell Tice       1006.0       2012.0

# %%
df
# Out:
#            Date       Company        Person Name  Room number  Double Room
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0       8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0       4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0       8024.0
# 3        Hotels           NaN                NaN          NaN          NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0       2012.0
# ..          ...           ...                ...          ...          ...
# 190   Cleartrip           NaN                NaN          NaN          NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0       8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0      10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0       2020.0
# 194      Hotels           NaN                NaN          NaN          NaN
#
# [195 rows x 5 columns]

# %%
df['Room number'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 190     True
# 191    False
# 192    False
# 193    False
# 194     True
# Name: Room number, Length: 195, dtype: bool

# %%
mask = df['Room number'].isna()

df['Text Value'] = np.where(mask, df['Date'], np.nan)
df
# Out:
#            Date       Company        Person Name  Room number  Double Room  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0       8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0       4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0       8024.0
# 3        Hotels           NaN                NaN          NaN          NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0       2012.0
# ..          ...           ...                ...          ...          ...
# 190   Cleartrip           NaN                NaN          NaN          NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0       8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0      10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0       2020.0
# 194      Hotels           NaN                NaN          NaN          NaN
#
#     Text Value
# 0          NaN
# 1          NaN
# 2          NaN
# 3       Hotels
# 4          NaN
# ..         ...
# 190  Cleartrip
# 191        NaN
# 192        NaN
# 193        NaN
# 194     Hotels
#
# [195 rows x 6 columns]

# %%
df['Text Value'].ffill(inplace=True)
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_23884\1347225950.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Text Value'].ffill(inplace=True)

# %%
df
# Out:
#            Date       Company          Person Name  Room number  Double Room  \
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0       2012.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0       6030.0
# 6    1-Jan-2022          Oozz         Deina Harwin       2005.0       4010.0
# 7    1-Jan-2022      Innotype    Benyamin Crocetti       2001.0       4002.0
# 10   1-Jan-2022          Jayo      Tate Manntschke       3014.0       6028.0
# ..          ...           ...                  ...          ...          ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0       2030.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0      14004.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0       8016.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0      10004.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0       2020.0
#
#     Text Value
# 4       Hotels
# 5       Hotels
# 6       Hotels
# 7       Hotels
# 10      Hotels
# ..         ...
# 186     Hotels
# 187     Hotels
# 191  Cleartrip
# 192  Cleartrip
# 193  Cleartrip
#
# [131 rows x 6 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#            Date       Company          Person Name  Room number  Double Room  \
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0       2012.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0       6030.0
# 6    1-Jan-2022          Oozz         Deina Harwin       2005.0       4010.0
# 7    1-Jan-2022      Innotype    Benyamin Crocetti       2001.0       4002.0
# 10   1-Jan-2022          Jayo      Tate Manntschke       3014.0       6028.0
# ..          ...           ...                  ...          ...          ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0       2030.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0      14004.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0       8016.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0      10004.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0       2020.0
#
#     Text Value
# 4       Hotels
# 5       Hotels
# 6       Hotels
# 7       Hotels
# 10      Hotels
# ..         ...
# 186     Hotels
# 187     Hotels
# 191  Cleartrip
# 192  Cleartrip
# 193  Cleartrip
#
# [131 rows x 6 columns]

# %%
df.value_counts('Text Value')
# Out:
# Text Value
# Hotels              34
# Expedia             33
# Cleartrip           26
# Booking             24
# Travel Agent 007    14
# Name: count, dtype: int64

# %%
df3 = df.value_counts('Text Value')
df3.plot()
# Out:
# <Axes: xlabel='Text Value'>

# %%
df3.plot.bar()
# Out:
# <Axes: xlabel='Text Value'>

# %%
df3.plot.pie()
# Out:
# <Axes: ylabel='count'>
